# %%
import numpy as np 
import matplotlib.pyplot as plt
import random
#def func(x):
    #return x+1
a,b=1,10
x=np.linspace(0,1,10)
x_random=np.array([random.random() for m in x])  
y=x+x_random
print (x,y)
figax=plt.subplots(figsize=(8,5))
plt.scatter(x,y)
plt.show()
# Out:
# [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  0.66666667 0.77777778 0.88888889 1.        ] [0.7029958  0.26318081 0.64826165 0.40700335 1.0445983  0.64922734
#  1.14151985 0.81500482 1.24265514 1.94486117]

# %%
import numpy as np 
import matplotlib.pyplot as plt
import random
def func(x):
    return 1.5*np.square((1-np.exp(-2*(x-0.5))))
a,b=1,10
x=np.linspace(0,5,100)
y=func(x)+random.uniform(0,1)
figax=plt.subplots(figsize=(8,5))
plt.scatter(x,y)
plt.show()
